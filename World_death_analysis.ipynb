# %% [markdown]
# <a href="https://colab.research.google.com/github/alcosoda/World-death-analysis/blob/main/World_death_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(3)
# Out:
# 3
